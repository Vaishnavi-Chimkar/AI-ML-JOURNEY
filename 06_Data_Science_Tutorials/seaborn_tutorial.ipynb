# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="ticks")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
print(type(tips))
print(tips.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(
    data = tips,
    x="total_bill",
    y="tip",
    hue = "smoker",
    size = "size",
    style = "smoker"
)

# %%
sns.relplot(
    data = tips,
    x="total_bill",
    y="tip",
    kind ="line",
    # hue = "smoker",
    # size = "size",
    # style = "smoker"
)

# %%
tips = sns.load_dataset("tips")
sns.scatterplot(
    data = tips,
    x = "total_bill",
    y = "tip",
    hue = "time"
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips = sns.load_dataset("tips")
sns.lineplot(
    data = tips,
    x = "total_bill",
    y = "tip",
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
flights = sns.load_dataset("flights")
sns.lineplot(
    data = flights,
    x = "year",
    y="passengers"
)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
tips = sns.load_dataset("tips")
sns.barplot(
    data = tips,
    x = "day",
    y = "tip",
    hue = "sex"
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
tips = sns.load_dataset("tips")
sns.boxplot(
    data = tips,
    x = "day",
    y = "tip",
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins = sns.load_dataset("penguins")
sns.histplot(
    data = penguins,
    x = "body_mass_g",
    bins = 20
)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
flight_pivot = flights.pivot(index="month",columns="year",values="passengers")
sns.heatmap(
    flight_pivot,
    cmap="coolwarm",
    annot = True,
    fmt = "d"
)
plt.title("Passengers Heatmap")
plt.tight_layout()

# %%
fig,ax = plt.subplots()

sns.lineplot(
    data = tips,
    x = "day",
    y = "total_bill",
    hue = "sex",
    ax = ax,
    marker = "o",
    errorbar = None
)
ax.set_title("avg bill value for each day")
ax.set_xlabel("Days")
ax.set_ylabel("Total Bill Amount")
fig.tight_layout()

# %%
import numpy as np
scores = np.random.normal(70,10,200)
sns.histplot(
    data = scores,
    bins = 30
)
plt.axvline(
    x = np.mean(scores),
    color = "red",
    linestyle = "--",
    linewidth = "2",
    label = f"Passing marks {np.mean(scores)}"
)

# %%
penguins = sns.load_dataset("penguins")
sns.scatterplot(
    data = penguins,
    x = "flipper_length_mm",
    y = "body_mass_g",
    hue = "species"
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
tips = sns.load_dataset("tips")
sns.boxplot(
    data = tips,
    x = "day",
    y = "total_bill",
    hue = "sex"
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips = sns.load_dataset("tips")
sns.scatterplot(
    data = tips,
    x = "day",
    y = "total_bill",
    hue = "sex",
    style = "smoker",
)
plt.title(" Total Bill Amount For Each Day")
plt.xlabel("Days")
plt.ylabel("Total Bill Amount")
# Out:
# Text(0, 0.5, 'Total Bill Amount')

# %%
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip_pivot = tips.pivot(index="day",columns="time",values="tip")
print(tip_pivot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 tip_pivot = tips.pivot(index="day",columns="time",values="tip")
#       2 print(tip_pivot)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:9366, in DataFrame.pivot(self, columns, index, values)
#    9359 @Substitution("")
#    9360 @Appender(_shared_docs["pivot"])
#    9361 def pivot(
#    9362     self, *, columns, index=lib.no_default, values=lib.no_default
#    9363 ) -> DataFrame:
#    9364     from pandas.core.reshape.pivot import pivot
# -> 9366     return pivot(self, index=index, columns=columns, values=values)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...
